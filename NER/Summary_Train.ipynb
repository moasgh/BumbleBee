# %%
import handlers as hl

# %%
hlm = hl.ModelHandler('load',None)

# %%
hlm.summary_train_by_test('GENIA-pos', ['rnn_single_crf'] , ['lookup', 'char-cnn', 'char-rnn'],
                         epochs = [10,501,10] , param = 'amacro_f1' , map_location = 0)
# Out:
# loading rnn_single_crf_lookup_GENIA-pos/rnn_single_crf.epoch10
# saved model: epoch = 10, loss = 15.016072
# {'UNIT': 'word', 'TASK': None, 'RNN_TYPE': 'LSTM', 'NUM_DIRS': 2, 'NUM_LAYERS': 10, 'BATCH_SIZE': 32, 'EMBED': {'lookup': 100}, 'HIDDEN_SIZE': 300, 'DROPOUT': 0.3, 'LEARNING_RATE': 0.0002, 'EVAL_EVERY': 10, 'SAVE_EVERY': 10, 'EPOCH': 600, 'model_name': 'rnn_single_crf', 'output_path': 'rnn_single_crf_lookup_GENIA-pos', 'EMBED_SIZE': 100, 'HRE': False}
# rnn_single_crf(
#   (rnn): rnn(
#     (embed): embed(
#       (word_embed): Embedding(19466, 100, padding_idx=0)
#     )
#     (rnn): LSTM(100, 150, num_layers=10, batch_first=True, dropout=0.3, bidirectional=True)
#     (out): Linear(in_features=300, out_features=45, bias=True)
#   )
#   (crf): crf()
# )
# ============ evaluation results ============
# 	amacro_f1 = 0.422751
#
# loading rnn_single_crf_char-cnn_GENIA-pos/rnn_single_crf.epoch10
# saved model: epoch = 10, loss = 54.017833
# ...
